# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
uploaded = files.upload()
print("File uploaded successfully!")
# Out:
#      <input type="file" id="files-cab0a0d8-2f4c-45b7-9b31-ece36bc6c1b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cab0a0d8-2f4c-45b7-9b31-ece36bc6c1b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)
print("Dataset loaded successfully!")
print("File name:", file_name)
# Out:
# Dataset loaded successfully!
# File name: seasonal_agriculture_performance_dataset (3).csv

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0        486.4               24.3          69.1                 5.8     7.14
# 1        855.4               25.7          78.4                 5.1     5.20
# 2        455.6               23.9          56.4                10.3     5.82
# 3        753.2               29.7          65.2                 6.3     5.98
# 4        101.6               34.1          55.2                 6.5     6.90
#
# ...

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3995        865.4               27.3          51.4                 6.3
# 3996        947.5               29.2          85.5                 6.1
# 3997         80.0               35.4          68.5                 8.6
# 3998        475.0               28.2          61.7                 6.4
# 3999        984.3               25.8          77.2                 5.9
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 4000
# Number of Columns: 28

# %%
print("Column Names:\n")
for i, column in enumerate(df.columns, 1):
    print(i, ".", column)
# Out:
# Column Names:
#
# 1 . Farm_ID
# 2 . State
# 3 . District
# 4 . Crop
# 5 . Season
# 6 . Farm_Area_Hectares
# 7 . Rainfall_mm
# 8 . Avg_Temperature_C
# 9 . Humidity_pct
# 10 . Sunlight_Hours_Day
# 11 . Soil_pH
# 12 . Soil_Moisture_pct
# 13 . Nitrogen_kg_ha
# 14 . Phosphorus_kg_ha
# 15 . Potassium_kg_ha
# 16 . Irrigation_Method
# 17 . Fertilizer_kg_ha
# 18 . Pesticide_Litre_ha
# 19 . Seed_Quality_Score
# 20 . Yield_Tonnes_Ha
# 21 . Production_Tonnes
# 22 . Market_Price_INR_Tonne
# 23 . Total_Cost_INR
# 24 . Revenue_INR
# 25 . Profit_INR
# 26 . Water_Used_m3
# 27 . Water_Efficiency_t_per_1000m3
# 28 . Disease_Pest_Risk_pct

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %%
missing_values = df.isnull().sum()
print("Missing Values in Each Column:\n")
print(missing_values)
# Out:
# Missing Values in Each Column:
#
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# ...

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_table = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': missing_percentage
})
missing_table
# Out:
#                                Missing Values  Percentage
# Farm_ID                                     0         0.0
# State                                       0         0.0
# District                                    0         0.0
# Crop                                        0         0.0
# Season                                      0         0.0
# Farm_Area_Hectares                          0         0.0
# Rainfall_mm                                48         1.2
# Avg_Temperature_C                           0         0.0
# Humidity_pct                                0         0.0
# Sunlight_Hours_Day                          0         0.0
# Soil_pH                                     0         0.0
# Soil_Moisture_pct                          40         1.0
# Nitrogen_kg_ha                              0         0.0
# Phosphorus_kg_ha                            0         0.0
# Potassium_kg_ha                             0         0.0
# ...

# %%
duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %%
df = df.drop_duplicates()
print("Dataset shape after removing duplicates:", df.shape)
# Out:
# Dataset shape after removing duplicates: (4000, 28)

# %%
df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
numeric_columns = df.select_dtypes(include=np.number).columns
categorical_columns = df.select_dtypes(include='object').columns
for column in numeric_columns:
    df[column] = df[column].fillna(df[column].median())
for column in categorical_columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(df[column].mode()[0])
print("Missing values handled successfully!")
# Out:
# Missing values handled successfully!

# %%
print(df.isnull().sum())
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
print("Seasons in the dataset:")
print(df['Season'].unique())
# Out:
# Seasons in the dataset:
# ['Kharif' 'Rabi' 'Zaid']

# %%
season_counts = df['Season'].value_counts()
print(season_counts)
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
season_counts.plot(kind='bar')
plt.title('Number of Farms by Season')
plt.xlabel('Season')
plt.ylabel('Number of Farms')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
crop_counts = df['Crop'].value_counts()
print(crop_counts)
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
crop_counts.plot(kind='bar')
plt.title('Distribution of Crops')
plt.xlabel('Crop')
plt.ylabel('Number of Farms')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
state_counts = df['State'].value_counts()
print(state_counts)
# Out:
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
state_counts.plot(kind='bar')
plt.title('Agricultural Records by State')
plt.xlabel('State')
plt.ylabel('Number of Farms')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
season_yield = df.groupby('Season')['Yield_Tonnes_Ha'].mean().sort_values(ascending=False)
print("Average Yield by Season:")
print(season_yield)
# Out:
# Average Yield by Season:
# Season
# Kharif    5.628612
# Rabi      5.039435
# Zaid      4.641313
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_yield.plot(kind='bar')
plt.title('Average Agricultural Yield by Season')
plt.xlabel('Season')
plt.ylabel('Average Yield (Tonnes/Ha)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_production = df.groupby('Season')['Production_Tonnes'].mean().sort_values(ascending=False)
print("Average Production by Season:")
print(season_production)
# Out:
# Average Production by Season:
# Season
# Kharif    46.311192
# Rabi      41.486712
# Zaid      38.886111
# Name: Production_Tonnes, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_production.plot(kind='bar')
plt.title('Average Production by Season')
plt.xlabel('Season')
plt.ylabel('Production (Tonnes)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_profit = df.groupby('Season')['Profit_INR'].mean().sort_values(ascending=False)
print("Average Profit by Season:")
print(season_profit)
# Out:
# Average Profit by Season:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_profit.plot(kind='bar')
plt.title('Average Profit by Season')
plt.xlabel('Season')
plt.ylabel('Average Profit (INR)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_revenue = df.groupby('Season')['Revenue_INR'].mean().sort_values(ascending=False)
print("Average Revenue by Season:")
print(season_revenue)
# Out:
# Average Revenue by Season:
# Season
# Kharif    710719.055649
# Rabi      601526.048556
# Zaid      519171.904040
# Name: Revenue_INR, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_revenue.plot(kind='bar')
plt.title('Average Revenue by Season')
plt.xlabel('Season')
plt.ylabel('Average Revenue (INR)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_cost = df.groupby('Season')['Total_Cost_INR'].mean().sort_values(ascending=False)
print("Average Cost by Season:")
print(season_cost)
# Out:
# Average Cost by Season:
# Season
# Zaid      543976.728956
# Kharif    531804.408094
# Rabi      513836.578365
# Name: Total_Cost_INR, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_cost.plot(kind='bar')
plt.title('Average Agricultural Cost by Season')
plt.xlabel('Season')
plt.ylabel('Average Cost (INR)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_rainfall = df.groupby('Season')['Rainfall_mm'].mean()
print("Average Rainfall by Season:")
print(season_rainfall)
# Out:
# Average Rainfall by Season:
# Season
# Kharif    849.199663
# Rabi      437.615366
# Zaid      304.654714
# Name: Rainfall_mm, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_rainfall.plot(kind='bar')
plt.title('Average Rainfall by Season')
plt.xlabel('Season')
plt.ylabel('Rainfall (mm)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_temperature = df.groupby('Season')['Avg_Temperature_C'].mean()
print("Average Temperature by Season:")
print(season_temperature)
# Out:
# Average Temperature by Season:
# Season
# Kharif    28.454019
# Rabi      23.489183
# Zaid      31.042088
# Name: Avg_Temperature_C, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_temperature.plot(kind='bar')
plt.title('Average Temperature by Season')
plt.xlabel('Season')
plt.ylabel('Average Temperature (°C)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_humidity = df.groupby('Season')['Humidity_pct'].mean()
print("Average Humidity by Season:")
print(season_humidity)
# Out:
# Average Humidity by Season:
# Season
# Kharif    71.812591
# Rabi      57.893178
# Zaid      52.012121
# Name: Humidity_pct, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_humidity.plot(kind='bar')
plt.title('Average Humidity by Season')
plt.xlabel('Season')
plt.ylabel('Humidity (%)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_water = df.groupby('Season')['Water_Used_m3'].mean().sort_values(ascending=False)
print("Average Water Usage by Season:")
print(season_water)
# Out:
# Average Water Usage by Season:
# Season
# Zaid      6419.893939
# Kharif    6102.201237
# Rabi      5846.987093
# Name: Water_Used_m3, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_water.plot(kind='bar')
plt.title('Average Water Usage by Season')
plt.xlabel('Season')
plt.ylabel('Water Used (m³)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_water_efficiency = df.groupby('Season')['Water_Efficiency_t_per_1000m3'].mean().sort_values(ascending=False)
print("Average Water Efficiency by Season:")
print(season_water_efficiency)
# Out:
# Average Water Efficiency by Season:
# Season
# Kharif    5.891834
# Rabi      5.186122
# Zaid      4.413239
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_water_efficiency.plot(kind='bar')
plt.title('Water Efficiency by Season')
plt.xlabel('Season')
plt.ylabel('Tonnes per 1000 m³')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_fertilizer = df.groupby('Season')['Fertilizer_kg_ha'].mean().sort_values(ascending=False)
print("Average Fertilizer Usage by Season:")
print(season_fertilizer)
# Out:
# Average Fertilizer Usage by Season:
# Season
# Kharif    187.077965
# Rabi      185.407068
# Zaid      184.638047
# Name: Fertilizer_kg_ha, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_fertilizer.plot(kind='bar')
plt.title('Average Fertilizer Usage by Season')
plt.xlabel('Season')
plt.ylabel('Fertilizer (kg/ha)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
season_risk = df.groupby('Season')['Disease_Pest_Risk_pct'].mean().sort_values(ascending=False)
print("Average Disease/Pest Risk by Season:")
print(season_risk)
# Out:
# Average Disease/Pest Risk by Season:
# Season
# Kharif    54.467903
# Rabi      40.482114
# Zaid      38.216667
# Name: Disease_Pest_Risk_pct, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_risk.plot(kind='bar')
plt.title('Disease and Pest Risk by Season')
plt.xlabel('Season')
plt.ylabel('Risk (%)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Rainfall_mm'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Rainfall vs Agricultural Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Avg_Temperature_C'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Temperature vs Agricultural Yield')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Fertilizer_kg_ha'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Fertilizer Usage vs Agricultural Yield')
plt.xlabel('Fertilizer (kg/ha)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Water_Used_m3'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Water Usage vs Agricultural Yield')
plt.xlabel('Water Used (m³)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Seed_Quality_Score'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Seed Quality vs Agricultural Yield')
plt.xlabel('Seed Quality Score')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Soil_Moisture_pct'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Soil Moisture vs Agricultural Yield')
plt.xlabel('Soil Moisture (%)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Soil_pH'], df['Yield_Tonnes_Ha'], alpha=0.5)
plt.title('Soil pH vs Agricultural Yield')
plt.xlabel('Soil pH')
plt.ylabel('Yield (Tonnes/Ha)')
plt.tight_layout()
plt.show()

# %%
correlation_columns = [
    'Rainfall_mm',
    'Avg_Temperature_C',
    'Humidity_pct',
    'Sunlight_Hours_Day',
    'Soil_pH',
    'Soil_Moisture_pct',
    'Nitrogen_kg_ha',
    'Phosphorus_kg_ha',
    'Potassium_kg_ha',
    'Fertilizer_kg_ha',
    'Pesticide_Litre_ha',
    'Seed_Quality_Score',
    'Yield_Tonnes_Ha',
    'Production_Tonnes',
    'Market_Price_INR_Tonne',
    'Total_Cost_INR',
    'Revenue_INR',
    'Profit_INR',
    'Water_Used_m3',
    'Water_Efficiency_t_per_1000m3',
    'Disease_Pest_Risk_pct'
]
correlation_matrix = df[correlation_columns].corr()
correlation_matrix
# Out:
#                                Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# Rainfall_mm                       1.000000           0.198492      0.521069
# Avg_Temperature_C                 0.198492           1.000000      0.138136
# Humidity_pct                      0.521069           0.138136      1.000000
# Sunlight_Hours_Day               -0.362779          -0.033863     -0.297298
# Soil_pH                           0.016657           0.029988      0.028447
# Soil_Moisture_pct                 0.508941           0.084001      0.446470
# Nitrogen_kg_ha                    0.007460           0.018707      0.001198
# Phosphorus_kg_ha                  0.020940           0.008508     -0.005963
# Potassium_kg_ha                   0.031373           0.022993     -0.003070
# Fertilizer_kg_ha                  0.024602           0.015861      0.024623
# Pesticide_Litre_ha                0.004058           0.006657     -0.004028
# ...

# %%
plt.figure(figsize=(16,12))
plt.imshow(correlation_matrix, aspect='auto')
plt.colorbar()
plt.xticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns,
    rotation=90
)
plt.yticks(
    range(len(correlation_matrix.columns)),
    correlation_matrix.columns
)
plt.title('Correlation Heatmap of Agricultural Variables')
plt.tight_layout()
plt.show()

# %%
yield_correlation = correlation_matrix['Yield_Tonnes_Ha'].sort_values(
    ascending=False
)
print("Correlation with Yield:")
print(yield_correlation)
# Out:
# Correlation with Yield:
# Yield_Tonnes_Ha                  1.000000
# Water_Efficiency_t_per_1000m3    0.912568
# Production_Tonnes                0.882813
# Profit_INR                       0.488466
# Revenue_INR                      0.432152
# Water_Used_m3                    0.386294
# Nitrogen_kg_ha                   0.053149
# Phosphorus_kg_ha                 0.047941
# Rainfall_mm                      0.030951
# Total_Cost_INR                   0.030622
# Disease_Pest_Risk_pct            0.014292
# Humidity_pct                     0.012297
# Soil_Moisture_pct                0.010999
# Avg_Temperature_C                0.009996
# Potassium_kg_ha                  0.003382
# Fertilizer_kg_ha                 0.000018
# Seed_Quality_Score              -0.007209
# Pesticide_Litre_ha              -0.007779
# Sunlight_Hours_Day              -0.015341
# Soil_pH                         -0.020672
# Market_Price_INR_Tonne          -0.382607
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
profit_correlation = correlation_matrix['Profit_INR'].sort_values(
    ascending=False
)
print("Correlation with Profit:")
print(profit_correlation)
# Out:
# Correlation with Profit:
# Profit_INR                       1.000000
# Revenue_INR                      0.887331
# Production_Tonnes                0.554172
# Water_Efficiency_t_per_1000m3    0.489487
# Yield_Tonnes_Ha                  0.488466
# Market_Price_INR_Tonne           0.225119
# Water_Used_m3                    0.190278
# Rainfall_mm                      0.107648
# Soil_Moisture_pct                0.091281
# Nitrogen_kg_ha                   0.085016
# Total_Cost_INR                   0.068356
# Disease_Pest_Risk_pct            0.067583
# Humidity_pct                     0.063775
# Phosphorus_kg_ha                 0.049747
# Potassium_kg_ha                  0.031192
# Seed_Quality_Score               0.010438
# Avg_Temperature_C                0.009043
# Soil_pH                         -0.013145
# Pesticide_Litre_ha              -0.025705
# Sunlight_Hours_Day              -0.054822
# Fertilizer_kg_ha                -0.073542
# Name: Profit_INR, dtype: float64

# %%
crop_yield = df.groupby('Crop')['Yield_Tonnes_Ha'].mean().sort_values(
    ascending=False
)
print("Average Yield by Crop:")
print(crop_yield)
# Out:
# Average Yield by Crop:
# Crop
# Sugarcane    46.642361
# Maize         2.710036
# Rice          2.431304
# Wheat         2.108013
# Chilli        1.542767
# Groundnut     1.322901
# Cotton        1.229783
# Pulses        0.921512
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(12,6))
crop_yield.plot(kind='bar')
plt.title('Average Yield by Crop')
plt.xlabel('Crop')
plt.ylabel('Average Yield (Tonnes/Ha)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
crop_profit = df.groupby('Crop')['Profit_INR'].mean().sort_values(
    ascending=False
)
print("Average Profit by Crop:")
print(crop_profit)
# Out:
# Average Profit by Crop:
# Crop
# Sugarcane    817187.986885
# Chilli       750878.342233
# Cotton       124546.915354
# Groundnut     44858.120283
# Pulses        -4238.052419
# Maize        -83978.326679
# Rice        -102213.504348
# Wheat       -123398.337134
# Name: Profit_INR, dtype: float64

# %%
plt.figure(figsize=(12,6))
crop_profit.plot(kind='bar')
plt.title('Average Profit by Crop')
plt.xlabel('Crop')
plt.ylabel('Average Profit (INR)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
irrigation_counts = df['Irrigation_Method'].value_counts()
print("Irrigation Methods:")
print(irrigation_counts)
# Out:
# Irrigation Methods:
# Irrigation_Method
# Flood        1310
# Rainfed      1041
# Drip          915
# Sprinkler     734
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
irrigation_counts.plot(kind='bar')
plt.title('Distribution of Irrigation Methods')
plt.xlabel('Irrigation Method')
plt.ylabel('Number of Farms')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
irrigation_yield = df.groupby(
    'Irrigation_Method'
)['Yield_Tonnes_Ha'].mean().sort_values(ascending=False)
print("Average Yield by Irrigation Method:")
print(irrigation_yield)
# Out:
# Average Yield by Irrigation Method:
# Irrigation_Method
# Drip         6.577989
# Sprinkler    5.160627
# Flood        4.863977
# Rainfed      4.602142
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(10,6))
irrigation_yield.plot(kind='bar')
plt.title('Average Yield by Irrigation Method')
plt.xlabel('Irrigation Method')
plt.ylabel('Yield (Tonnes/Ha)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
season_crop_yield = pd.pivot_table(
    df,
    values='Yield_Tonnes_Ha',
    index='Crop',
    columns='Season',
    aggfunc='mean'
)
season_crop_yield
# Out:
# Season        Kharif       Rabi       Zaid
# Crop
# Chilli      1.731459   1.465031   1.195312
# Cotton      1.374512   1.198358   0.960217
# Groundnut   1.484974   1.233164   1.037778
# Maize       2.966410   2.603648   2.290952
# Pulses      1.036063   0.875962   0.669677
# Rice        2.698376   2.322847   1.900490
# Sugarcane  53.459120  43.286124  38.423922
# Wheat       2.253664   2.057468   1.748588

# %%
plt.figure(figsize=(12,8))
plt.imshow(season_crop_yield, aspect='auto')
plt.colorbar(label='Average Yield (Tonnes/Ha)')
plt.xticks(
    range(len(season_crop_yield.columns)),
    season_crop_yield.columns
)
plt.yticks(
    range(len(season_crop_yield.index)),
    season_crop_yield.index
)
plt.xlabel('Season')
plt.ylabel('Crop')
plt.title('Average Crop Yield Across Seasons')
plt.tight_layout()
plt.show()

# %%
season_crop_profit = pd.pivot_table(
    df,
    values='Profit_INR',
    index='Crop',
    columns='Season',
    aggfunc='mean'
)
season_crop_profit
# Out:
# Season           Kharif           Rabi           Zaid
# Crop
# Chilli     9.543804e+05  638572.496933  448659.093750
# Cotton     2.169995e+05  107343.587065  -53925.336957
# Groundnut  1.082654e+05   10416.542373  -68872.500000
# Maize     -3.933267e+04  -89133.403433 -194049.166667
# Pulses     4.333890e+04  -14309.136150 -139227.806452
# Rice      -6.490340e+04  -98427.868613 -227239.343137
# Sugarcane  1.000791e+06  731612.860465  583635.803922
# Wheat     -1.058719e+05 -119954.565401 -193208.952941

# %%
best_yield_season = season_yield.idxmax()
best_yield_value = season_yield.max()
best_profit_season = season_profit.idxmax()
best_profit_value = season_profit.max()
print("Best Season for Average Yield:")
print(best_yield_season, "=", round(best_yield_value, 2), "Tonnes/Ha")
print("\nBest Season for Average Profit:")
print(best_profit_season, "=", round(best_profit_value, 2), "INR")
# Out:
# Best Season for Average Yield:
# Kharif = 5.63 Tonnes/Ha
#
# Best Season for Average Profit:
# Kharif = 178914.65 INR

# %%
lowest_yield_season = season_yield.idxmin()
lowest_yield_value = season_yield.min()
lowest_profit_season = season_profit.idxmin()
lowest_profit_value = season_profit.min()
print("Lowest Season for Average Yield:")
print(lowest_yield_season, "=", round(lowest_yield_value, 2), "Tonnes/Ha")
print("\nLowest Season for Average Profit:")
print(lowest_profit_season, "=", round(lowest_profit_value, 2), "INR")
# Out:
# Lowest Season for Average Yield:
# Zaid = 4.64 Tonnes/Ha
#
# Lowest Season for Average Profit:
# Zaid = -24804.82 INR

# %%
best_crop = crop_yield.idxmax()
best_crop_yield = crop_yield.max()
print("Highest Yielding Crop:")
print(best_crop)
print("Average Yield:", round(best_crop_yield, 2), "Tonnes/Ha")
# Out:
# Highest Yielding Crop:
# Sugarcane
# Average Yield: 46.64 Tonnes/Ha

# %%
best_profit_crop = crop_profit.idxmax()
best_profit_crop_value = crop_profit.max()
print("Most Profitable Crop:")
print(best_profit_crop)
print("Average Profit:", round(best_profit_crop_value, 2), "INR")
# Out:
# Most Profitable Crop:
# Sugarcane
# Average Profit: 817187.99 INR

# %%
print("=" * 60)
print("SEASONAL AGRICULTURE PERFORMANCE ANALYSIS")
print("=" * 60)
print("\nDATASET INFORMATION")
print("-" * 60)
print("Total Records:", len(df))
print("Total Features:", len(df.columns))
print("Number of Seasons:", df['Season'].nunique())
print("Number of Crops:", df['Crop'].nunique())
print("Number of States:", df['State'].nunique())
print("\nSEASONAL PERFORMANCE")
print("-" * 60)
print(
    "Highest Average Yield Season:",
    best_yield_season,
    "(",
    round(best_yield_value, 2),
    "Tonnes/Ha)"
)
print(
    "Highest Average Profit Season:",
    best_profit_season,
    "(",
    round(best_profit_value, 2),
    "INR)"
)
print(
    "Lowest Average Yield Season:",
    lowest_yield_season,
    "(",
    round(lowest_yield_value, 2),
    "Tonnes/Ha)"
)
print(
    "Lowest Average Profit Season:",
    lowest_profit_season,
    "(",
    round(lowest_profit_value, 2),
    "INR)"
)
print("\nCROP PERFORMANCE")
print("-" * 60)
print(
    "Highest Yielding Crop:",
    best_crop,
    "(",
    round(best_crop_yield, 2),
    "Tonnes/Ha)"
)
print(
    "Most Profitable Crop:",
    best_profit_crop,
    "(",
    round(best_profit_crop_value, 2),
    "INR)"
)
print("\nWATER PERFORMANCE")
print("-" * 60)
best_water_season = season_water_efficiency.idxmax()
print(
    "Most Water-Efficient Season:",
    best_water_season
)
print("\n" + "=" * 60)
# Out:
# ...
# SEASONAL AGRICULTURE PERFORMANCE ANALYSIS
# ...
#
# DATASET INFORMATION
# ------------------------------------------------------------
# Total Records: 4000
# Total Features: 28
# Number of Seasons: 3
# Number of Crops: 8
# Number of States: 8
#
# SEASONAL PERFORMANCE
# ------------------------------------------------------------
# Highest Average Yield Season: Kharif ( 5.63 Tonnes/Ha)
# Highest Average Profit Season: Kharif ( 178914.65 INR)
# Lowest Average Yield Season: Zaid ( 4.64 Tonnes/Ha)
# Lowest Average Profit Season: Zaid ( -24804.82 INR)
#
# CROP PERFORMANCE
# ------------------------------------------------------------
# Highest Yielding Crop: Sugarcane ( 46.64 Tonnes/Ha)
# Most Profitable Crop: Sugarcane ( 817187.99 INR)
#
# WATER PERFORMANCE
# ------------------------------------------------------------
# Most Water-Efficient Season: Kharif
#
# ...

# %%
fig = plt.figure(figsize=(18,12))
ax1 = plt.subplot(2,3,1)
season_yield.plot(kind='bar', ax=ax1)
ax1.set_title('Average Yield by Season')
ax1.set_xlabel('Season')
ax1.set_ylabel('Yield (Tonnes/Ha)')
ax1.tick_params(axis='x', rotation=0)
ax2 = plt.subplot(2,3,2)
season_profit.plot(kind='bar', ax=ax2)
ax2.set_title('Average Profit by Season')
ax2.set_xlabel('Season')
ax2.set_ylabel('Profit (INR)')
ax2.tick_params(axis='x', rotation=0)
ax3 = plt.subplot(2,3,3)
season_rainfall.plot(kind='bar', ax=ax3)
ax3.set_title('Average Rainfall by Season')
ax3.set_xlabel('Season')
ax3.set_ylabel('Rainfall (mm)')
ax3.tick_params(axis='x', rotation=0)
ax4 = plt.subplot(2,3,4)
season_water.plot(kind='bar', ax=ax4)
ax4.set_title('Average Water Usage')
ax4.set_xlabel('Season')
ax4.set_ylabel('Water Used (m³)')
ax4.tick_params(axis='x', rotation=0)
ax5 = plt.subplot(2,3,5)
crop_yield.plot(kind='bar', ax=ax5)
ax5.set_title('Average Yield by Crop')
ax5.set_xlabel('Crop')
ax5.set_ylabel('Yield (Tonnes/Ha)')
ax5.tick_params(axis='x', rotation=45)
ax6 = plt.subplot(2,3,6)
season_risk.plot(kind='bar', ax=ax6)
ax6.set_title('Disease/Pest Risk by Season')
ax6.set_xlabel('Season')
ax6.set_ylabel('Risk (%)')
ax6.tick_params(axis='x', rotation=0)
plt.suptitle(
    'Seasonal Agriculture Performance Analysis Dashboard',
    fontsize=18
)
plt.tight_layout()
plt.show()

# %%
print("KEY FINDINGS")
print("=" * 70)
print(
    f"1. {best_yield_season} has the highest average agricultural "
    f"yield of {best_yield_value:.2f} Tonnes/Ha."
)
print(
    f"2. {lowest_yield_season} has the lowest average agricultural "
    f"yield of {lowest_yield_value:.2f} Tonnes/Ha."
)
print(
    f"3. {best_profit_season} provides the highest average profit "
    f"of ₹{best_profit_value:,.2f}."
)
print(
    f"4. {lowest_profit_season} has the lowest average profit "
    f"of ₹{lowest_profit_value:,.2f}."
)
print(
    f"5. {best_crop} has the highest average yield among the "
    f"crops in the dataset."
)
print(
    f"6. {best_profit_crop} has the highest average profit among "
    f"the crops analyzed."
)
print(
    f"7. {best_water_season} has the highest average water "
    f"efficiency among the seasons."
)
print(
    f"8. The correlation analysis can be used to identify "
    f"environmental and resource variables associated with yield."
)
print("=" * 70)
# Out:
# KEY FINDINGS
# ...
# 1. Kharif has the highest average agricultural yield of 5.63 Tonnes/Ha.
# 2. Zaid has the lowest average agricultural yield of 4.64 Tonnes/Ha.
# 3. Kharif provides the highest average profit of ₹178,914.65.
# 4. Zaid has the lowest average profit of ₹-24,804.82.
# 5. Sugarcane has the highest average yield among the crops in the dataset.
# 6. Sugarcane has the highest average profit among the crops analyzed.
# 7. Kharif has the highest average water efficiency among the seasons.
# 8. The correlation analysis can be used to identify environmental and resource variables associated with yield.
# ...
